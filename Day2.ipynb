# %% [markdown]
# <a href="https://colab.research.google.com/github/isathik/Day1-test/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **DR. Sathik Day2**

# %% [markdown]
# Testing saving

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.plot(data['sepal_width'])
plt.show()

# %%
data[['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
data[['sepal_length']]
# Out:
#      sepal_length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %%
data.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
plt.plot(data['petal_length'])
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.show()

# %%
plt.plot(data["petal_length"],color = "green")
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.show()

# %%
data.shape
# Out:
# (150, 5)

# %%
data.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
plt.plot(data['petal_length'],color = 'green')
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(data['petal_length'],color = 'green')
plt.plot(data['petal_width'],color = 'red')
plt.plot(data['sepal_length'],color = 'blue')
plt.plot(data['sepal_width'],color = 'black')
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,4))
plt.plot(data['petal_length'],color = 'green',label="petal length")
plt.plot(data['petal_width'],color = 'red', label = "petal width", linestyle ="--")
plt.plot(data['sepal_length'],color = 'blue',label="sepal length")
plt.plot(data['sepal_width'],color = 'black',label="sepal width", linestyle ="--")
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(data['petal_length'],color = 'green',label="petal length")
plt.plot(data['petal_width'],color = 'red', label = "petal width", linestyle ="--",marker="+")
plt.plot(data['sepal_length'],color = 'blue',label="sepal length")
plt.plot(data['sepal_width'],color = 'black',label="sepal width", linestyle ="--", marker = "*")
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.grid()
plt.plot(data['petal_length'],color = 'green',label="petal length")
plt.plot(data['petal_width'],color = 'red', label = "petal width", linestyle ="--",marker="+")
plt.plot(data['sepal_length'],color = 'blue',label="sepal length")
plt.plot(data['sepal_width'],color = 'black',label="sepal width", linestyle ="--", marker = "*")
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure(figsize=(8,4))
plt.grid()
plt.style.use('fivethirtyeight')
plt.plot(data['petal_length'],color = 'green',label="petal length")
plt.plot(data['petal_width'],color = 'red', label = "petal width", linestyle ="--",marker="+")
plt.plot(data['sepal_length'],color = 'blue',label="sepal length")
plt.plot(data['sepal_width'],color = 'black',label="sepal width", linestyle ="--", marker = "*")
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.legend()
plt.show()
plt.plot(data['petal_length'],color = 'green',label="petal length")
plt.plot(data['petal_width'],color = 'red', label = "petal width", linestyle ="--",marker="+")
plt.plot(data['sepal_length'],color = 'blue',label="sepal length")
plt.plot(data['sepal_width'],color = 'black',label="sepal width", linestyle ="--", marker = "*")
plt.title("Line chart - petal length", fontsize=27) 
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.legend()
plt.show()

# %%
#plt.bar(data["species"], data["sepal_length"])
#plt.bar(data["species"],data["sepal_width"])
plt.bar(data["species"], data["petal_length"])
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
